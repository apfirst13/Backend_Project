# %% [markdown]
# - หลักการเขียนโปรแกรม
#   1. เขียนให้เสร็จ
#   2. ทำให้อ่านง่าย
#   3. comment
#      <br>wrc
#
# ###
#
# fuc = ชุดคำสั่งเรียงซ้ำ

# %% [markdown]
# ## <span style="color:red"> Project </span>: guess number
#
# ###
#
# - <span > Requirment :</span>
#   It is a CLI-based game, so you need to use the command line to interact with the game. The game should work as follows:
#
# When the game starts, it should display a welcome message along with the rules of the game. <text style="color:red" >check</text>
#
# The computer should randomly select a number between 1 and 100.<text style="color:red" >check</text>
#
# User should select the difficulty level (easy, medium, hard) which will determine the number of chances they get to guess the number.<text style="color:red" >check</text>
#
# The user should be able to enter their guess.<text style="color:red" >check</text>
#
# If the user's guess is correct, the game should display a congratulatory message along with the number of attempts it took to guess the number. <text style="color:red" >check</text>
#
# If the user's guess is incorrect, the game should display a message indicating whether the number is greater or less than the user's guess. <text style="color:red" >check</text>
#
# The game should end when the user guesses the correct number or runs out of chances. <text style="color:red" >check</text>

# %%
import sys

print(f"Original recursion limit: {sys.getrecursionlimit()}")
# Out:
# Original recursion limit: 4000

# %%
import sys

# Optional: Print the current default recursion limit
print(f"Original recursion limit: {sys.getrecursionlimit()}")

# Set a new recursion limit (e.g., 2000)
# Use this with caution: setting it too high can cause a C stack overflow and crash Python.
new_limit = 4000
sys.setrecursionlimit(new_limit)

print(f"New recursion limit: {sys.getrecursionlimit()}")

"""
# Example recursive function
def deep_recursion(depth):
    if depth < new_limit:
        deep_recursion(depth + 1)
    else:
        print(f"Reached maximum depth of {depth}")

# Call the function
deep_recursion(1)

"""
# Out:
# Original recursion limit: 4000
# New recursion limit: 4000
# '\n# Example recursive function\ndef deep_recursion(depth):\n    if depth < new_limit:\n        deep_recursion(depth + 1)\n    else:\n        print(f"Reached maximum depth of {depth}")\n\n# Call the function\ndeep_recursion(1)\n\n'

# %%
import random  # libraly random
import time

n = random.randrange(1, 100)  # varible random number
# print(n)

c = [10, 5, 3]  # chacne


def display():
    """display welcome message"""

    print("Welcome to the Number Guessing Game!")
    print("I'm thinking of a number between 1 and 100.")
    print("You have 3 to 10 chances to guess the correct number.\n")
    print(
        "Please select the difficulty level:\n1. Easy (10 chances)\n2. Medium (5 chances)\n3. Hard (3 chances)\n"
    )

def Random():

    print(f"Ans : {n} ")
    c = [10, 5, 3]  # chacne
    t = 0  # time of guess
    g = None # guess
    l = 0  # level
    r = []  # round play
    
    # display() #display func

    # l = int(input("Enter your choice: {1, 2, 3}"))  # input level
    # print(f"Enter your level {1, 2, 3} : {c}\n")  # select level
    l=3
    start=time.time() #timer playing

    if l == 1:
        print(
            "Great! You have selected the Easy difficulty level.\nLet's start the game!"
        )

        for i in range(c[0]):
            hint(l, t)  # cal func hint
            if g == n:
                t += 1
                break
        else:
            Guess(g, t)
            t += 1
    if l == 2:
        print(
            "Great! You have selected the Medium difficulty level.\nLet's start the game!"
        )

        for i in range(c[1]):
            hint(l, t)  # cal func hint
            if g == n:
                t += 1
                break
            else:
                Guess(g, t)
                t += 1

    if l == 3:

        print(
            "Great! You have selected the Hard difficulty level.\nLet's start the game!\n"
        )
        # print("1",g,n,t,r)
        for i in range(c[2]):
            hint(l, t)  # cal func hint
            g = int(input("guess number"))
            # print("2",g, n,r)
            if g == n:
                t+=1
                Guess(g,t)
                # print("3", g, n,t,r)
                break
            elif g != n:

                Guess(g,t)
                t += 1

    # print(f"Ans : {n} ")
    # print("htest0", l, t, r)
    end= time.time() 
    Time(start, end)  # total time func
    r = r.append(1)
    highscore(l, t, r) # r in  func is None
    replay()  # play again func


def Guess(g, t):  # guess func
    # g = int(input("guess number"))  # input guess num
    # print(f"Enter your guess: {g}")

    if g > n:
        print(f"Incorrect! The number is less than {g}\n")

    elif g < n:
        print(f"Incorrect! The number is more than {g}\n")

    elif g==n:
        # print(f"Congratulations! You guessed the correct number in {t} attempts.\n")
        return  print(
            f"Congratulations! You guessed the correct number in {t} attempts.\n"
        )

# %%
# Random()

# %% [markdown]
# - add more feature
#
# ###
#
# Allow the user to play multiple rounds of the game (i.e., keep playing until the user decides to quit). You can do this by asking the user if they want to play again after each round.<text style="color:red" >check</text>
#
# Add a timer to see how long it takes the user to guess the number.<text style="color:red" >check</text>
#
# Implement a hint system that provides clues to the user if they are stuck.<text style="color:red" >check</text>
#
# Keep track of the user's high score (i.e., the fewest number of attempts it took to guess the number under a specific difficulty level).<text style="color:red" >check</text>

# %%
import time


def replay():
    print("want to play again?")
    print("Yes or No --> Enter [y,n] = [1,0]\n")
    # p = str(input("Enter to play again"))

    # if p == "1" or p == "y":
    #     Random()
    # else:
    #     print("Thank For Playing")
    Random()

def Time(start,end):
    # start = time.time()
    # # Random()
    # end = time.time()
    
    print(f"Total time: {end - start:.2f} seconds\n")


def hint(l, t):
    # print(f"show out put :{l,t}")
    # print(lt)
    match l:
        case 1:
            # print("test")
            if t >= 7:
                print(f"Hint :\nthe number between{n-7} and {n+7}")
        case 2:
            if t >= 3:
                print(f"Hint :\nthe number between{n-5} and {n+5}")
        case 3:
            # print("test", l, t)
            if t >= 2:
                print(f"Hint :\nthe number between{n-3} and {n+3}")


def highscore(l,t,r): #track fewwest attempt(time)
    # input level , time
    """
    ติดตามคะแนนสูงสุดของผู้ใช้ 
    (เช่น จำนวนครั้งที่น้อยที่สุดในการเดาตัวเลขภายใต้ระดับความยากเฉพาะ)

    """
    h1 = []
    h2 = []
    h3 = []
    val=0
    r = []
    #  #ถ้า ไม่มีค่าในdata จะloop ไม่ได้

    match l:
        case 1:
            nh = len(h1)
            h1 = h2.append(t)
            for nh in h1:
                if nh < h1[i + 1]:
                    nh = h1[i + 1]
            print(f"the fewest attemp in Hard level is{h1[nh]}]\n")
        case 2:
            nh = len(h2)
            h3 = h3.append(t)
            for nh in h2:
                if nh < h2[i + 1]:
                    nh = h2[i + 1]
            print(f"the fewest attemp in Hard level is{h2[nh]}]\n")
        case 3:
            print("htest2 : ",l,t,r)
            # print("list",h3,)
            # loop รับค่า แล้วค่อยเปรียบเทียบเพื่อแสดงผล
                for i in h3:
                    print("htest3 : ", l, t, r)
                    print(t)
                    h3 = i.append(t)
                    # print(h3)
            print(r)
            #         for i in h3:
            #         # if nh <=1:
            #         #     break
            #             if nh < h3[i + 1]:
            #                 nh = h3[i + 1]
            #                 val = h3[nh]
            #     print(f"the fewest attemp in Hard level is : {val}]\n")
            # # print(type(t))
            # print(h3)
            # for nh in h3:
            #     if nh <=1:
            #         break
            #     elif nh < h3[i + 1]:
            #         nh = h3[i + 1]

# %%
Random()
# Out:
# Ans : 62
# Great! You have selected the Hard difficulty level.
# Let's start the game!
#
# Congratulations! You guessed the correct number in 1 attempts.
#
# Total time: 1.66 seconds
#
# htest2 :  3 1 []
# htest3 :  3 1 []
# []
# want to play again?
# Yes or No --> Enter [y,n] = [1,0]
#
# Ans : 62
# Great! You have selected the Hard difficulty level.
# Let's start the game!
#
# Congratulations! You guessed the correct number in 1 attempts.
#
# Total time: 2.67 seconds
#
# htest2 :  3 1 []
# htest3 :  3 1 []
# []
# want to play again?
# Yes or No --> Enter [y,n] = [1,0]
#
# Ans : 62
# Great! You have selected the Hard difficulty level.
# Let's start the game!
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[185], line 1
# ----> 1 Random()
#
# Cell In[182], line 89, in Random()
#      87 r = r.append(1)
#      88 highscore(l, t, r) # r in  func is None
# ...

# %%
#test code
# highscore(l,t)
# h3 = [3, 2, 3, 1, 2, 1]
# for  in h3:
#     if i < h3[i + 1]:
#         i = h3[i + 1]

# print(f"the fewest attemp in Hard level is{h3[i]}]\n")

# highscore(l,t,r)
