# %%
import sys #interact with python 
import json  # libray about use python manage json  file
import os

# %%
command = sys.argv[1]  # input : add, del,list
task = []

if command == "add":
    # ทำงานเกี่ยวกับการเพิ่มงาน
    # print(sys.argv)
    # print("Command : ", command)
    title = sys.argv[2]
    # print(title)
    # print("you want to add :", title)
    task.append(title)
    # print(task)
    with open("test.json", "w") as f:
        json.dump(task, f) #convert into json
elif command == "delete":
    # ลบงาน
    pass
elif command == "list":
    # แสดงงาน
    pass
elif command == "test":
    print("test")

else:
    print("Unknown command")
# Out:
# Unknown command

# %%
# task =["a","b"]

# %%
if os.path.exists("tasks.json"):
    with open("tasks.json", "r") as f:
        tasks = json.load(f)
